# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
base_thoracic = pd.read_csv("ThoraricSurgery.csv")

# %%
base_thoracic
# Out:
#       id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0      1  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1      2  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2      3  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3      4  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4      5  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F
# ..   ...   ...   ...   ...   ...  ...  ...  ...   ...   ...   ...   ...   ...
# 465  466  DGN2  3.88  2.12  PRZ1    F    F    F     T     F  OC13     F     F
# 466  467  DGN3  3.76  3.12  PRZ0    F    F    F     F     F  OC11     F     F
# 467  468  DGN3  3.04  2.08  PRZ1    F    F    F     T     F  OC13     F     F
# 468  469  DGN3  1.96  1.68  PRZ1    F    F    F     T     T  OC12     F     F
# 469  470  DGN3  4.72  3.56  PRZ0    F    F    F     F     F  OC12     F     F
#
# ...

# %%
base_thoracic.columns
# Out:
# Index(['id', 'DGN', 'PRE4', 'PRE5', 'PRE6', 'PRE7', 'PRE8', 'PRE9', 'PRE10',
#        'PRE11', 'PRE14', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32', 'AGE',
#        'Risk1Yr'],
#       dtype='object')

# %%
base_thoracic.head(5)
# Out:
#    id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0   1  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1   2  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2   3  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3   4  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4   5  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F
#
#   PRE25 PRE30 PRE32  AGE Risk1Yr
# 0     F     T     F   60       F
# 1     F     T     F   51       F
# 2     F     T     F   59       F
# 3     F     F     F   54       F
# 4     F     T     F   73       T

# %%
#["id"]
base_thoracic = base_thoracic.drop(columns=["id"])

# %%
#['DGN', 'PRE4', 'PRE5', 'PRE6', 'PRE7', 'PRE8', 'PRE9', 'PRE10','PRE11', 'PRE14', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32']

categorica = pd.get_dummies(base_thoracic, columns=['DGN', 'PRE4', 'PRE5', 'PRE6', 'PRE7', 'PRE8', 'PRE9', 'PRE10','PRE11', 'PRE14', 'PRE17', 'PRE19', 'PRE25', 'PRE30', 'PRE32'])

# %%
categorica
# Out:
#      AGE Risk1Yr  DGN_DGN1  DGN_DGN2  DGN_DGN3  DGN_DGN4  DGN_DGN5  DGN_DGN6  \
# 0     60       F     False      True     False     False     False     False
# 1     51       F     False     False      True     False     False     False
# 2     59       F     False     False      True     False     False     False
# 3     54       F     False     False      True     False     False     False
# 4     73       T     False     False      True     False     False     False
# ..   ...     ...       ...       ...       ...       ...       ...       ...
# 465   63       F     False      True     False     False     False     False
# 466   61       F     False     False      True     False     False     False
# 467   52       F     False     False      True     False     False     False
# 468   79       F     False     False      True     False     False     False
# 469   51       F     False     False      True     False     False     False
#
# ...

# %%
y = categorica["Risk1Yr"]
x = categorica.drop(columns=["Risk1Yr"])

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3, random_state=28)

# %%
modelo = DecisionTreeClassifier()

modelo.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
modelo.acuracia = modelo.score(xtest,ytest)
modelo.acuracia
# Out:
# 0.7872340425531915
