# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
base_tyreoid = pd.read_csv("thyroidDF.csv")

# %%
base_tyreoid.head(50)
["T4U", ""]
# Out:
#     age  sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 0    29    F            f                  f                   f    f
# 1    29    F            f                  f                   f    f
# 2    41    F            f                  f                   f    f
# 3    36    F            f                  f                   f    f
# 4    32    F            f                  f                   f    f
# 5    60    F            f                  f                   f    f
# 6    77    F            f                  f                   f    f
# 7    28    F            f                  f                   f    f
# 8    28    F            f                  f                   f    f
# 9    28    F            f                  f                   f    f
# 10   54    F            f                  f                   f    f
# 11   42    F            f                  f                   f    f
# 12   51    M            t                  f                   f    f
# 13   51    F            f                  f                   f    f
# 14   37    F            f                  f                   f    f
# 15   16    M            f                  f                   f    f
# 16   54    F            f                  f                   f    f
# 17   43    M            f                  f                   f    f
# 18   63    F            t                  f                   f    t
# 19   36    F            f                  f                   f    f
# 20   40    F            f                  t                   f    f
# 21   40    F            f                  f                   f    f
# 22   40    F            f                  f                   f    f
# 23   77    F            f                  f                   f    f
# 24   77  NaN            f                  f                   f    f
# 25   77    F            f                  f                   f    f
# 26   77    F            f                  f                   f    f
# 27   51    F            f                  f                   f    f
# 28   75    F            f                  f                   f    f
# 29   56    M            f                  f                   f    f
# 30   42    M            f                  f                   f    f
# 31   85    M            f                  f                   f    f
# 32   41    M            f                  f                   f    f
# 33   71    F            t                  f                   f    f
# 34   67    M            f                  f                   f    f
# 35   67    M            f                  f                   f    f
# 36   51    F            f                  f                   f    f
# 37   51    F            f                  f                   f    f
# 38   28    F            f                  f                   f    f
# 39   55    F            t                  f                   f    f
# 40   32    F            t                  f                   f    f
# 41   61    F            t                  f                   f    f
# 42   46    M            f                  f                   f    f
# 43   41    F            f                  f                   f    f
# 44   44    F            t                  f                   f    f
# 45   51    F            f                  f                   f    t
# 46   29    M            f                  f                   f    f
# 47   41    F            f                  f                   f    f
# 48   82    M            f                  f                   f    f
# 49   64    F            t                  f                   f    f
#
#    pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 0         f               f              f                 t  ...    NaN
# 1         f               f              f                 f  ...  128.0
# 2         f               f              f                 f  ...    NaN
# 3         f               f              f                 f  ...    NaN
# 4         f               f              f                 f  ...    NaN
# 5         f               f              f                 f  ...    NaN
# 6         f               f              f                 f  ...    NaN
# 7         f               f              f                 f  ...  116.0
# 8         f               f              f                 f  ...   76.0
# 9         f               f              f                 f  ...   83.0
# 10        f               f              f                 f  ...  133.0
# 11        f               f              f                 f  ...  105.0
# 12        f               f              f                 f  ...    NaN
# 13        f               f              f                 f  ...  116.0
# 14        f               f              f                 f  ...    NaN
# 15        f               f              f                 f  ...    NaN
# 16        f               f              f                 f  ...  122.0
# 17        f               f              f                 f  ...  116.0
# 18        f               f              f                 f  ...   48.0
# 19        f               f              f                 t  ...   90.0
# 20        f               f              f                 f  ...   79.0
# 21        f               f              f                 f  ...  104.0
# 22        f               f              f                 f  ...   88.0
# 23        f               f              f                 f  ...  107.0
# 24        f               f              f                 f  ...  126.0
# 25        f               f              f                 f  ...  113.0
# 26        f               f              f                 f  ...  150.0
# 27        f               f              f                 f  ...   93.0
# 28        f               f              f                 f  ...  157.0
# 29        f               f              f                 f  ...   80.0
# 30        f               f              f                 f  ...   91.0
# 31        f               f              f                 f  ...   47.0
# 32        f               f              f                 f  ...   39.0
# 33        f               f              f                 f  ...  126.0
# 34        f               f              f                 f  ...   71.0
# 35        f               f              f                 f  ...   88.0
# 36        f               f              f                 f  ...  104.0
# 37        f               f              f                 t  ...  111.0
# 38        f               f              f                 f  ...   86.0
# 39        f               f              f                 t  ...  136.0
# 40        f               f              f                 f  ...  163.0
# 41        f               f              f                 f  ...  118.0
# 42        f               f              f                 t  ...   82.0
# 43        f               f              f                 f  ...   33.0
# 44        f               f              f                 f  ...  134.0
# 45        f               f              f                 f  ...   60.0
# 46        f               f              f                 f  ...  102.0
# 47        f               f              f                 f  ...   97.0
# 48        f               f              f                 t  ...  115.0
# 49        f               f              f                 f  ...   86.0
#
#    T4U_measured   T4U FTI_measured    FTI TBG_measured   TBG  referral_source  \
# 0             f   NaN            f    NaN            f   NaN            other
# 1             f   NaN            f    NaN            f   NaN            other
# 2             f   NaN            f    NaN            t  11.0            other
# 3             f   NaN            f    NaN            t  26.0            other
# 4             f   NaN            f    NaN            t  36.0            other
# 5             f   NaN            f    NaN            t  26.0            other
# 6             f   NaN            f    NaN            t  21.0            other
# 7             f   NaN            f    NaN            f   NaN              SVI
# 8             f   NaN            f    NaN            f   NaN            other
# 9             f   NaN            f    NaN            f   NaN            other
# 10            f   NaN            f    NaN            f   NaN            other
# 11            f   NaN            f    NaN            f   NaN            other
# 12            f   NaN            f    NaN            f   NaN            other
# 13            f   NaN            f    NaN            f   NaN            other
# 14            f   NaN            f    NaN            f   NaN            other
# 15            f   NaN            f    NaN            f   NaN            other
# 16            f   NaN            f    NaN            f   NaN             SVHC
# 17            f   NaN            f    NaN            f   NaN            other
# 18            t  1.02            t   47.0            f   NaN            other
# 19            t  1.06            t   85.0            f   NaN            other
# 20            t  0.94            t   84.0            f   NaN            other
# 21            t  1.08            t   96.0            f   NaN            other
# 22            t  0.84            t  105.0            f   NaN            other
# 23            t  1.13            t   95.0            f   NaN            other
# 24            f   NaN            f    NaN            f   NaN             SVHC
# 25            t  1.07            t  106.0            f   NaN            other
# 26            f   NaN            f    NaN            f   NaN             SVHC
# 27            t  0.87            t  106.0            f   NaN              SVI
# 28            t  0.89            t  176.0            f   NaN              SVI
# 29            t  0.62            t  129.0            f   NaN              SVI
# 30            t  0.91            t  100.0            f   NaN              SVI
# 31            t  0.68            t   69.0            f   NaN              SVI
# 32            t  1.00            t   39.0            f   NaN            other
# 33            t  1.38            t   91.0            f   NaN            other
# 34            t  0.79            t   90.0            f   NaN            other
# 35            t  0.95            t   93.0            f   NaN              SVI
# 36            t  1.57            t   66.0            f   NaN              SVI
# 37            t  0.92            t  121.0            f   NaN            other
# 38            t  0.92            t   93.0            f   NaN            other
# 39            t  1.48            t   92.0            f   NaN            other
# 40            t  0.94            t  173.0            f   NaN            other
# 41            t  1.10            t   93.0            f   NaN            other
# 42            t  0.70            t  117.0            f   NaN            other
# 43            t  1.07            t   31.0            f   NaN            other
# 44            t  1.13            t  113.0            f   NaN            other
# 45            t  0.89            t   67.0            f   NaN              SVI
# 46            t  1.01            t  101.0            f   NaN              SVI
# 47            t  1.05            t   92.0            f   NaN              SVI
# 48            t  0.91            t  126.0            f   NaN              SVI
# 49            t  0.96            t   90.0            f   NaN            other
#
#    target  patient_id
# 0       -   840801013
# 1       -   840801014
# 2       -   840801042
# 3       -   840803046
# 4       S   840803047
# 5       -   840803048
# 6       -   840803068
# 7       -   840807019
# 8       -   840808060
# 9       -   840808073
# 10      -   840810016
# 11      -   840813022
# 12      -   840813060
# 13      -   840813068
# 14      -   840814014
# 15      -   840814057
# 16      -   840815016
# 17      -   840815020
# 18      F   840815067
# 19      -   840815068
# 20      -   840815069
# 21      -   840816001
# 22      -   840816002
# 23      -   840816003
# 24      -   840816004
# 25      -   840816005
# 26      -   840816006
# 27      -   840816007
# 28     AK   840816008
# 29      -   840816009
# 30      -   840816010
# 31      -   840816011
# 32      R   840816013
# 33      I   840816014
# 34      -   840816022
# 35      -   840816025
# 36      -   840816028
# 37      -   840816029
# 38      -   840816046
# 39      M   840816047
# 40      N   840816049
# 41      -   840816052
# 42      -   840816060
# 43      F   840816061
# 44      -   840816063
# 45      -   840816069
# 46      -   840816070
# 47      -   840816071
# 48      -   840816072
# 49      -   840816076
#
# [50 rows x 31 columns]

# %%
base_tyreoid.
# Out:
#   Cell In[30], line 1
#     base_tyreoid.
#                  ^
# SyntaxError: invalid syntax

# %%
# Out:
#       age sex on_thyroxine query_on_thyroxine on_antithyroid_meds sick  \
# 167    40   F            f                  f                   f    f
# 5256   35   F            f                  f                   f    f
# 6044   77   F            f                  f                   f    f
# 6045   73   M            f                  f                   f    f
# 6747   77   F            f                  f                   f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...    TT4  \
# 167         f               f              f                 f  ...    3.9
# 5256        f               t              f                 f  ...   73.0
# 6044        f               f              f                 f  ...  120.0
# 6045        f               f              f                 f  ...   89.0
# 6747        f               f              f                 f  ...  131.0
#
#      T4U_measured   T4U FTI_measured    FTI TBG_measured   TBG  \
# 167             t  0.83            t    5.0            t  28.0
# 5256            t  1.16            t   63.0            t  37.0
# 6044            t  0.96            t  124.0            t  45.0
# 6045            t  0.74            t  119.0            t  24.0
# 6747            t  1.04            t  126.0            t  25.0
#
#       referral_source target  patient_id
# 167             other      F   840827019
# 5256            other      -   851128040
# 6044              SVI      -   860305064
# 6045              SVI      -   860305065
# 6747              SVI      K   860702030
#
# [5 rows x 31 columns]
