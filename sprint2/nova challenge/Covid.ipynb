# %%
import pandas as pd

# %%
base = pd.read_csv('obitos-2024.csv')

# %%
#O local onde a pessoa estava faz crescer, diminuir ou não tem relação com o número de óbitos?
#Qual o tipo de doença que mais causa óbito?
#Qual a faixa etária que mais causa óbito a domicílio?
#Qual a faixa etária que mais causa morte por pneumonia em hospitais.
# Out:
#        uf tipo_doenca  local_obito faixa_etaria sexo  total
# 0      AC      OUTRAS    DOMICILIO          < 9    F      3
# 1      AC      OUTRAS    DOMICILIO          < 9    M      6
# 2      AC      OUTRAS     HOSPITAL          < 9    F     18
# 3      AC      OUTRAS     HOSPITAL          < 9    I      1
# 4      AC      OUTRAS     HOSPITAL          < 9    M     22
# ...    ..         ...          ...          ...  ...    ...
# 10256  TO   PNEUMONIA  VIA_PUBLICA          N/I    F      1
# 10257  TO  SEPTICEMIA     HOSPITAL          N/I    F      7
# 10258  TO  SEPTICEMIA     HOSPITAL          N/I    I      1
# 10259  TO  SEPTICEMIA     HOSPITAL          N/I    M     18
# 10260  TO        SRAG     HOSPITAL          N/I    F      1
#
# [10261 rows x 6 columns]
