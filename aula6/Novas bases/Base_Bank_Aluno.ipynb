# %%
import pandas as pd

# %%
base = pd.read_csv('bank-full.csv', delimiter=';')

# %%
base
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
base["pdays"].value_counts()
# Out:
# pdays
# -1      36954
#  182      167
#  92       147
#  91       126
#  183      126
#         ...
#  449        1
#  452        1
#  648        1
#  595        1
#  530        1
# Name: count, Length: 559, dtype: int64

# %%
base.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
base["poutcome"].value_counts()
# Out:
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %%
#1 - Faça a dummificação nas variáveis categóricas.
# conv = {
#     "no" : 0,
#     "yes": 1
# }
# base["default"] = base["default"].replace(conv)
# base["housing"] = base["housing"].replace(conv)
# base["loan"] = base["loan"].replace(conv)


from pyparsing import col



categorica = pd.get_dummies(base, columns=["job","marital", "education","default", "housing", "loan", "contact", "month", "poutcome"])

# %%
base.drop(columns=["job","marital", "education","default", "housing", "loan", "contact", "month", "poutcome"])
# Out:
#        age  balance  day  duration  campaign  pdays  previous    y
# 0       58     2143    5       261         1     -1         0   no
# 1       44       29    5       151         1     -1         0   no
# 2       33        2    5        76         1     -1         0   no
# 3       47     1506    5        92         1     -1         0   no
# 4       33        1    5       198         1     -1         0   no
# ...    ...      ...  ...       ...       ...    ...       ...  ...
# 45206   51      825   17       977         3     -1         0  yes
# 45207   71     1729   17       456         2     -1         0  yes
# 45208   72     5715   17      1127         5    184         3  yes
# 45209   57      668   17       508         4     -1         0   no
# 45210   37     2971   17       361         2    188        11   no
#
# [45211 rows x 8 columns]

# %%
base2 = pd.concat([base, categorica], axis=1)

base2
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
#Variaveis categoricas default, housing, loan, marital


#2 - Separes as bases em variáveis independentes e dependentes.
from matplotlib.pylab import RandomState
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier


x= base2.drop(columns= "loan")
y = base2["loan"]

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state= 28)
#3 - Crie a base de treino e de teste.
modelo = RandomForestClassifier()

modelo.fit([xtrain],[ytrain])

#4 - Crie o classificador
#5 - Avalie o classificador
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13724\363174861.py in ?()
#      13 xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state= 28)
#      14 #3 - Crie a base de treino e de teste.
#      15 modelo = RandomForestClassifier()
#      16
# ---> 17 modelo.fit([xtrain],[ytrain])
#      18
#      19 #4 - Crie o classificador
#      20 #5 - Avalie o classificador
#
# c:\Users\rcm20\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ...
